# %%
import random as rd
ladder={1:38,4:14,8:31,21:42,28:84,51:67,72:91,81:99}
snake={32:10,34:6,48:26,62:18,88:24,95:56,97:78}
pos1=0
pos2=0
def move(pos):
    dice=rd.randint(1,6)
    print("dice:{dice}")
    pos=pos+dice
    if pos in snake:
        print("bitten by snake")
        pos=snake[pos]
        print(f"position:{pos}")
    elif pos in ladder:
        print("went to next step")
        pos=ladder[pos]
        print(f"position:{pos}")
    else:
        print(f"position:{pos}")
    return pos

# %%
ladder={1:38,4:14,8:31,21:42,28:84,51:67,72:91,81:99}
snake={32:10,34:6,48:26,62:18,88:24,95:56,97:78}
pos1=0
pos2=0
def move(pos):
    dice=rd.randint(1,6)
    print(dice)
    pos=pos+dice
    if pos in snake:
        print("bitten by snake")
        pos=snake[pos]
        print(pos)
    elif pos in ladder:
        print("went to next step")
        pos=ladder[pos]
        print(pos)
    else:
        print(pos)
    return pos

# %%
while True:
    A=input("enter player 1 to throw dice:")
    pos1=move(pos1)
    if pos1>=100:
        print("player 1 wins")
        break
    B=input("enter player 2 to throw dice:")
    pos2=move(pos2)
    if pos2>=100:
        print("player 2 wins")
        break
# Out:
# enter player 1 to throw dice:
# 2
# 2
# enter player 2 to throw dice:
# 3
# 3
# enter player 1 to throw dice:
# 1
# 3
# enter player 2 to throw dice:
# 3
# 6
# enter player 1 to throw dice:
# 4
# 7
# enter player 2 to throw dice:
# 2
# went to next step
# 31
# enter player 1 to throw dice:
# 3
# 10
# enter player 2 to throw dice:
# 2
# 33
# enter player 1 to throw dice:
# 6
# 16
# enter player 2 to throw dice:
# 1
# bitten by snake
# 6
# enter player 1 to throw dice:
# 2
# 18
# enter player 2 to throw dice:
# 2
# went to next step
# 31
# enter player 1 to throw dice:
# 1
# 19
# enter player 2 to throw dice:
# 2
# 33
# enter player 1 to throw dice:
# 1
# 20
# enter player 2 to throw dice:
# 2
# 35
# enter player 1 to throw dice:
# 3
# 23
# enter player 2 to throw dice:
# 6
# 41
# enter player 1 to throw dice:
# 4
# 27
# enter player 2 to throw dice:
# 5
# 46
# enter player 1 to throw dice:
# 6
# 33
# enter player 2 to throw dice:
# 2
# bitten by snake
# 26
# ...
